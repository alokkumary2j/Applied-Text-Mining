# %%
import tensorflow as tf
import numpy as np

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disabl

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

#filename = maybe_download('text8.zip', 31344016)
filename = maybe_download('text8_small.zip', 9403323)
# Out:
# Found and verified text8_small.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
print(filename)
words = read_data(filename)
print('Data size', len(words))

# Step 2: Build the dictionary and replace rare words with UNK token.
#vocabulary_size = 50000
vocabulary_size = 5000
def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# text8_small.zip
# Data size 1604152
# Most common words (+UNK) [['UNK', 237412], ('the', 100788), ('of', 58449), ('one', 42521), ('and', 39818)]
# Sample data [1090, 3044, 13, 7, 191, 2, 4193, 48, 61, 139] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3044 originated -> 13 as
# 3044 originated -> 1090 anarchism
# 13 as -> 7 a
# 13 as -> 3044 originated
# 7 a -> 191 term
# 7 a -> 13 as
# 191 term -> 7 a
# 191 term -> 2 of

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 30     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                     num_sampled, vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.initialize_all_variables()
#Bug Here [AttributeError: 'module' object has no attribute 'global_variables_initializer']
#Hence Changed global_variables_initializer to initialize_all_variables

# %%
# Step 5: Begin training.
#num_steps = 100001
num_steps = 70001
final_embeddings=None
with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print("Initialized")

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
      print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~>>")
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  195.295730591
# Nearest to in: conversion, golden, lines, anno, oxford, hector, affair, honour,
# Nearest to eight: driving, domain, goddess, activities, rothbard, missions, mayor, damaged,
# Nearest to seven: lasting, taliban, contexts, leaders, concentrated, place, reports, him,
# Nearest to they: onto, joan, apl, photographs, flowers, study, interview, jersey,
# Nearest to with: nobel, producers, biblical, facts, fell, meeting, geometry, nicene,
# Nearest to of: equipment, jefferson, disaster, clay, sons, boat, discuss, geographic,
# Nearest to nine: melbourne, amongst, mayor, johann, medicine, cd, avenue, not,
# Nearest to has: isolated, opera, dimensional, hit, real, socialist, scottish, superior,
# Nearest to into: provincial, federal, feet, scientists, items, pa, gained, abbot,
# Nearest to and: schweitzer, designs, weeks, lateral, settlement, hard, da, histories,
# Nearest to have: heavier, formerly, warrior, destruction, rapidly, civilian, attempting, quote,
# Nearest to so: stronger, ion, quality, millions, thinking, ne, stream, carl,
# Nearest to all: fort, start, weapon, metals, diseases, varieties, case, speed,
# Nearest to war: el, argues, proposal, poetry, provincial, seem, kinds, deeply,
# Nearest to or: cf, accepted, width, limit, nervous, scholars, crimes, reliable,
# Nearest to such: amaranth, canonical, gregory, asbestos, colours, russell, resulting, sweden,
# Nearest to history: methane, accepted, judgment, considerable, confederation, actor, master, returns,
# Nearest to many: salts, areas, rich, via, capitalist, everything, sea, grown,
# Nearest to had: produced, anarcho, algorithms, hume, exposure, sensory, decisions, drawn,
# Nearest to his: pope, advance, marie, lewis, bible, viii, strait, dating,
# Nearest to which: conquered, roots, label, uncle, play, included, military, alp,
# Nearest to time: bob, reduction, agency, statements, en, annual, lacking, scene,
# Nearest to to: pain, archaea, tank, code, vary, rates, down, however,
# Nearest to five: executed, maria, selling, aphrodite, descent, prize, voting, reaches,
# Nearest to as: daily, le, attempt, apparent, partially, legend, mile, scene,
# Nearest to six: specifically, deals, democracy, till, turkey, fine, yard, police,
# Nearest to no: characteristics, result, buddhism, driving, real, multiplication, centauri, situation,
# Nearest to d: humanity, activist, dispute, finish, sina, simon, essentially, north,
# Nearest to are: both, according, o, sir, boundaries, fertile, efforts, wright,
# Nearest to between: irish, consonant, catalan, lower, fight, rodin, habits, stories,
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~>>
# Average loss at step  2000 :  22.1865329833
# Average loss at step  4000 :  5.17033969641
# Average loss at step  6000 :  4.68335929739
# Average loss at step  8000 :  4.54153256834
# Average loss at step  10000 :  4.48015708339
# Nearest to in: of, from, nine, and, for, on, shah, stream,
# Nearest to eight: nine, four, zero, usa, domain, driving, six, aberdeen,
# Nearest to seven: nine, zero, anna, two, contexts, five, lasting, iliad,
# Nearest to they: joan, onto, actually, apl, wire, heavy, action, airport,
# Nearest to with: courts, meeting, in, fell, through, communion, of, and,
# Nearest to of: in, and, nine, boat, from, driver, agave, el,
# Nearest to nine: zero, anatomy, four, eight, six, seven, three, agave,
# Nearest to has: isolated, socialist, opera, scottish, problem, superior, dimensional, provide,
# Nearest to into: provincial, items, federal, feet, advocated, and, gained, eight,
# Nearest to and: or, plan, in, of, awards, nine, usa, courts,
# Nearest to have: destruction, attempting, charles, heavier, formerly, federation, single, civilian,
# Nearest to so: stream, ion, stronger, carl, millions, anarchists, survived, too,
# Nearest to all: fort, start, honor, awards, weapon, diseases, brief, metals,
# Nearest to war: el, argues, poetry, provincial, kinds, UNK, japan, proposal,
# Nearest to or: and, cf, width, accepted, reliable, e, scholars, nine,
# Nearest to such: aberdeen, courts, russell, canonical, injured, usage, sweden, leads,
# Nearest to history: methane, confederation, accepted, bottom, considerable, judgment, made, slightly,
# Nearest to many: areas, capitalist, rich, salts, via, everything, big, vietnam,
# Nearest to had: anarcho, algorithms, expression, is, exposure, produced, strictly, hume,
# Nearest to his: pope, the, mac, amino, knight, arts, legislation, author,
# Nearest to which: conquered, roots, uncle, label, awards, think, alp, limits,
# Nearest to time: bob, reduction, scene, annual, agency, island, statements, karpov,
# Nearest to to: code, flight, agave, regularly, in, trading, photos, down,
# Nearest to five: nine, three, zero, descent, seven, kennedy, two, aphrodite,
# Nearest to as: legend, scene, attempt, partially, apparent, aol, sometimes, courts,
# Nearest to six: nine, zero, eight, four, UNK, specifically, resulted, march,
# Nearest to no: a, buddhism, situation, characteristics, addiction, result, flight, multiplication,
# Nearest to d: humanity, activist, colorado, simon, one, agave, dispute, circuits,
# Nearest to are: is, efforts, anatomy, lover, o, civilian, were, technique,
# Nearest to between: lower, consonant, irish, fight, aol, stories, interpretation, catalan,
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~>>
# Average loss at step  12000 :  4.41731048799
# Average loss at step  14000 :  4.3241728605
# Average loss at step  16000 :  4.36451378345
# Average loss at step  18000 :  4.43655640554
# Average loss at step  20000 :  4.40907013237
# Nearest to in: on, from, at, nine, for, of, with, and,
# Nearest to eight: nine, four, zero, six, two, five, UNK, three,
# Nearest to seven: nine, zero, two, five, one, four, six, eight,
# Nearest to they: joan, actually, onto, it, he, wire, heavy, minnesota,
# Nearest to with: in, and, through, meeting, courts, by, fell, for,
# Nearest to of: and, in, nine, milne, boat, for, driver, from,
# Nearest to nine: eight, zero, six, seven, four, five, two, one,
# Nearest to has: is, isolated, was, socialist, opera, dimensional, superior, scottish,
# Nearest to into: items, and, provincial, from, federal, in, advocated, gained,
# Nearest to and: or, UNK, nine, courts, of, awards, plan, agave,
# Nearest to have: attempting, are, be, destruction, formerly, federation, were, potential,
# Nearest to so: survived, ion, too, stream, stronger, anarchists, carl, millions,
# Nearest to all: fort, start, honor, weapon, diseases, awards, sixth, brief,
# Nearest to war: el, poetry, argues, provincial, kinds, recently, varieties, japan,
# Nearest to or: and, cf, UNK, width, e, nine, reliable, alexandria,
# Nearest to such: aberdeen, amaranth, russell, injured, sweden, canonical, usage, asbestos,
# Nearest to history: methane, confederation, bottom, accepted, judgment, considerable, slightly, made,
# Nearest to many: areas, capitalist, salts, rich, via, the, vietnam, big,
# Nearest to had: expression, anarcho, is, was, algorithms, linear, strictly, decisions,
# Nearest to his: the, their, pope, mac, changed, knight, speech, amino,
# Nearest to which: conquered, roots, uncle, that, think, and, this, awards,
# Nearest to time: reduction, annual, scene, bob, island, existence, karpov, four,
# Nearest to to: not, cannot, for, code, nine, agave, archaea, regularly,
# Nearest to five: nine, zero, eight, three, seven, two, UNK, four,
# Nearest to as: legend, scene, attempt, object, by, partially, mile, apparent,
# Nearest to six: nine, eight, zero, two, four, UNK, one, seven,
# Nearest to no: a, situation, buddhism, centauri, addiction, flowers, kurosawa, aka,
# Nearest to d: b, one, activist, humanity, simon, circuits, agave, colorado,
# Nearest to are: is, were, was, have, difranco, lover, anatomy, civilian,
# Nearest to between: lower, consonant, irish, rodin, fight, interpretation, catalan, habits,
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~>>
# Average loss at step  22000 :  4.39255967844
# Average loss at step  24000 :  4.42046938682
# Average loss at step  26000 :  4.33959900486
# Average loss at step  28000 :  4.32407511568
# Average loss at step  30000 :  4.28520129061
# Nearest to in: on, nine, agave, from, seven, of, at, with,
# Nearest to eight: nine, six, four, five, zero, seven, three, agave,
# Nearest to seven: nine, eight, six, zero, five, four, agave, three,
# Nearest to they: he, it, actually, we, there, joan, i, onto,
# Nearest to with: through, agave, in, meeting, by, fell, courts, for,
# Nearest to of: cpc, agave, in, nine, eight, driver, for, boat,
# Nearest to nine: eight, seven, zero, six, agave, five, four, three,
# Nearest to has: is, was, isolated, had, have, socialist, radar, problem,
# Nearest to into: from, items, in, federal, provincial, advocated, gained, as,
# Nearest to and: or, agave, one, plan, linguistic, campaigns, aesthetic, truly,
# Nearest to have: are, be, attempting, agave, had, were, has, formerly,
# Nearest to so: too, ion, survived, stream, anarchists, millions, amstrad, stronger,
# Nearest to all: fort, start, honor, weapon, level, diseases, sixth, asbestos,
# Nearest to war: el, poetry, argues, provincial, kinds, varieties, recently, deeply,
# Nearest to or: and, cf, nine, e, width, genera, fruit, involves,
# Nearest to such: sweden, injured, well, aberdeen, amaranth, russell, agave, canonical,
# Nearest to history: confederation, bottom, methane, accepted, agave, video, made, rules,
# Nearest to many: areas, capitalist, some, salts, via, rich, these, products,
# Nearest to had: was, have, expression, has, is, algorithms, anarcho, were,
# Nearest to his: their, the, mac, pope, agave, her, s, knight,
# Nearest to which: that, this, conquered, uncle, roots, think, one, it,
# Nearest to time: reduction, scene, four, annual, island, bob, period, existence,
# Nearest to to: agave, nine, not, seven, cannot, down, will, code,
# Nearest to five: eight, six, nine, three, seven, zero, four, two,
# Nearest to as: agave, legend, attempt, scene, mile, himself, department, tissue,
# Nearest to six: eight, nine, zero, four, seven, five, three, two,
# Nearest to no: a, nine, situation, eight, buddhism, addiction, centauri, require,
# Nearest to d: b, one, activist, simon, circuits, humanity, cpc, agave,
# Nearest to are: were, is, have, was, agave, lover, zero, be,
# Nearest to between: lower, irish, seven, consonant, rodin, catalan, habits, interpretation,
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~>>
# Average loss at step  32000 :  4.29232374275
# Average loss at step  34000 :  4.27056417418
# Average loss at step  36000 :  4.2377024312
# Average loss at step  38000 :  4.19259549332
# Average loss at step  40000 :  4.2262603296
# Nearest to in: agave, at, on, from, nine, of, seven, eight,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to seven: nine, eight, six, four, five, zero, three, two,
# Nearest to they: he, we, it, there, actually, joan, onto, agave,
# Nearest to with: agave, through, meeting, in, by, fell, courts, for,
# Nearest to of: cpc, agave, eight, nine, in, el, driver, and,
# Nearest to nine: eight, six, seven, zero, four, five, three, agave,
# Nearest to has: is, was, had, have, isolated, radar, dimensional, provide,
# Nearest to into: from, items, federal, in, advocated, provincial, gained, mid,
# Nearest to and: or, agave, campaigns, plan, one, american, which, who,
# Nearest to have: be, had, has, are, attempting, were, agave, formerly,
# Nearest to so: too, survived, ion, stream, stronger, amstrad, millions, carl,
# Nearest to all: fort, start, honor, level, sixth, asbestos, diseases, hank,
# Nearest to war: el, poetry, varieties, argues, provincial, kinds, recently, layer,
# Nearest to or: and, cf, e, than, nine, UNK, seven, fruit,
# Nearest to such: sweden, well, injured, canonical, enjoyed, russell, usage, these,
# Nearest to history: bottom, confederation, methane, agave, accepted, below, video, pattern,
# Nearest to many: some, these, areas, several, capitalist, the, salts, products,
# Nearest to had: was, have, has, expression, anarcho, algorithms, were, is,
# Nearest to his: their, the, her, agave, mac, s, its, pope,
# Nearest to which: that, this, think, roots, uncle, and, conquered, it,
# Nearest to time: reduction, period, scene, annual, island, four, existence, concentrated,
# Nearest to to: agave, not, cannot, down, will, seven, photos, nine,
# Nearest to five: eight, six, four, nine, zero, three, seven, two,
# Nearest to as: legend, agave, attempt, scene, earliest, anarchists, by, became,
# Nearest to six: eight, nine, four, seven, five, three, zero, two,
# Nearest to no: a, situation, addiction, require, centauri, judge, flowers, individuals,
# Nearest to d: b, agave, activist, one, simon, cpc, circuits, colorado,
# Nearest to are: were, is, have, was, be, fighting, agave, tests,
# Nearest to between: lower, irish, consonant, rodin, catalan, seven, towards, interpretation,
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~>>
# Average loss at step  42000 :  4.30832958555
# Average loss at step  44000 :  4.28811953402
# Average loss at step  46000 :  4.27329485857
# Average loss at step  48000 :  4.30548275208
# Average loss at step  50000 :  4.5711065681
# Nearest to in: agave, on, from, during, at, nine, of, explain,
# Nearest to eight: nine, six, seven, four, five, three, zero, agave,
# Nearest to seven: eight, nine, four, six, five, three, zero, agave,
# Nearest to they: he, we, there, it, actually, i, onto, joan,
# Nearest to with: agave, through, meeting, in, fell, by, for, few,
# Nearest to of: agave, cpc, boat, in, same, for, nine, during,
# Nearest to nine: eight, seven, six, five, four, agave, three, zero,
# Nearest to has: is, had, was, have, isolated, socialist, radar, problem,
# Nearest to into: from, federal, items, agave, provincial, in, advocated, make,
# Nearest to and: agave, or, campaigns, calling, histories, plan, finds, amos,
# Nearest to have: had, has, are, be, were, attempting, agave, formerly,
# Nearest to so: too, survived, ion, stream, grew, stronger, millions, went,
# Nearest to all: fort, start, honor, level, sixth, varieties, different, weapon,
# Nearest to war: poetry, el, varieties, provincial, argues, kinds, aalto, layer,
# Nearest to or: and, agave, than, cf, wave, fruit, e, genera,
# Nearest to such: well, sweden, these, agave, injured, bros, enjoyed, usage,
# Nearest to history: bottom, confederation, methane, agave, video, rules, made, accepted,
# Nearest to many: some, several, these, areas, the, both, capitalist, agave,
# Nearest to had: has, have, was, expression, anarcho, were, algorithms, rather,
# Nearest to his: their, her, the, mac, agave, its, s, care,
# Nearest to which: that, this, think, roots, uncle, it, agave, UNK,
# Nearest to time: reduction, period, annual, scene, four, island, characteristic, existence,
# Nearest to to: agave, will, cannot, not, down, would, should, photos,
# Nearest to five: six, four, eight, seven, three, nine, zero, two,
# Nearest to as: agave, legend, earliest, scene, himself, became, attempt, tissue,
# Nearest to six: eight, five, four, seven, nine, three, zero, agave,
# Nearest to no: a, nine, agave, situation, centauri, require, addiction, flowers,
# Nearest to d: b, simon, circuits, activist, agave, colorado, sina, truly,
# Nearest to are: were, is, have, be, agave, was, tests, lover,
# Nearest to between: lower, irish, rodin, consonant, towards, avenue, desert, catalan,
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~>>
# Average loss at step  52000 :  4.25162586355
# Average loss at step  54000 :  4.20304045296
# Average loss at step  56000 :  4.23651174629
# Average loss at step  58000 :  4.20928894484
# Average loss at step  60000 :  4.1771040529
# Nearest to in: agave, nine, seven, eight, from, six, during, of,
# Nearest to eight: nine, seven, five, six, four, three, zero, agave,
# Nearest to seven: eight, nine, six, five, four, three, zero, agave,
# Nearest to they: we, he, there, it, actually, onto, agave, you,
# Nearest to with: agave, meeting, through, in, doctrine, contained, fell, progress,
# Nearest to of: agave, cpc, nine, eight, in, six, seven, driver,
# Nearest to nine: eight, seven, five, six, four, zero, agave, three,
# Nearest to has: had, is, have, was, isolated, publicly, radar, provide,
# Nearest to into: from, items, federal, advocated, in, on, through, largest,
# Nearest to and: agave, one, or, campaigns, UNK, plan, american, amos,
# Nearest to have: had, has, be, were, are, agave, attempting, formerly,
# Nearest to so: too, survived, ion, stream, grew, went, removed, stronger,
# Nearest to all: fort, start, honor, level, possess, sixth, varieties, different,
# Nearest to war: poetry, varieties, el, battle, provincial, argues, aalto, agave,
# Nearest to or: and, agave, cf, than, e, wave, daughter, nine,
# Nearest to such: these, well, sweden, agave, injured, known, bros, many,
# Nearest to history: bottom, confederation, agave, methane, video, made, rules, australia,
# Nearest to many: some, several, these, capitalist, areas, both, agave, products,
# Nearest to had: has, have, was, were, expression, by, anarcho, rather,
# Nearest to his: their, her, the, agave, mac, its, s, care,
# Nearest to which: that, this, uncle, think, one, roots, and, it,
# Nearest to time: reduction, period, island, four, scene, annual, concentrated, karpov,
# Nearest to to: agave, will, cannot, should, down, nine, not, would,
# Nearest to five: eight, six, seven, nine, four, three, zero, agave,
# Nearest to as: agave, legend, earliest, four, UNK, six, mile, himself,
# Nearest to six: eight, five, seven, four, nine, three, zero, agave,
# Nearest to no: a, nine, agave, judge, yes, addiction, situation, centauri,
# Nearest to d: b, one, agave, simon, activist, circuits, and, truly,
# Nearest to are: were, is, have, be, agave, exist, tests, claims,
# Nearest to between: lower, irish, rodin, avenue, towards, desert, consonant, catalan,
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~>>
# Average loss at step  62000 :  4.11721498752
# Average loss at step  64000 :  4.17570939386
# Average loss at step  66000 :  4.24478676546
# Average loss at step  68000 :  4.22723424566
# Average loss at step  70000 :  4.21241608584
# Nearest to in: agave, nine, at, during, from, on, since, within,
# Nearest to eight: six, nine, seven, five, four, three, agave, zero,
# Nearest to seven: eight, four, six, five, nine, three, zero, agave,
# Nearest to they: he, we, there, it, actually, you, i, agave,
# Nearest to with: agave, in, meeting, through, doctrine, contained, than, few,
# Nearest to of: agave, nine, eight, same, in, cpc, boat, driver,
# Nearest to nine: eight, seven, six, five, four, agave, zero, three,
# Nearest to has: had, have, is, was, isolated, publicly, takes, appeared,
# Nearest to into: from, in, on, federal, items, through, combine, advocated,
# Nearest to and: or, agave, but, nine, UNK, digital, which, seven,
# Nearest to have: had, has, are, be, were, attempting, agave, formerly,
# Nearest to so: too, survived, ion, grew, removed, stream, went, recently,
# Nearest to all: fort, start, honor, level, possess, varieties, sixth, different,
# Nearest to war: varieties, poetry, el, aalto, battle, provincial, layer, argues,
# Nearest to or: and, UNK, agave, than, wave, daughter, e, cf,
# Nearest to such: these, well, sweden, many, known, agave, injured, bros,
# Nearest to history: bottom, confederation, agave, methane, made, nine, video, eight,
# Nearest to many: some, several, these, both, areas, capitalist, agave, products,
# Nearest to had: has, have, was, expression, were, anarcho, rather, algorithms,
# Nearest to his: their, her, the, its, agave, mac, s, organisation,
# Nearest to which: that, this, think, uncle, roots, agave, these, it,
# Nearest to time: reduction, period, annual, scene, four, island, existence, concentrated,
# Nearest to to: agave, will, cannot, not, should, down, nine, would,
# Nearest to five: six, four, eight, seven, nine, three, zero, two,
# Nearest to as: agave, legend, earliest, attempt, himself, agrippina, produce, mile,
# Nearest to six: eight, five, four, seven, nine, three, agave, zero,
# Nearest to no: a, nine, agave, any, judge, addiction, higher, centauri,
# Nearest to d: b, agave, simon, activist, one, sina, truly, circuits,
# Nearest to are: were, is, have, be, agave, tests, exist, do,
# Nearest to between: lower, irish, rodin, avenue, towards, desert, consonant, with,
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~>>

# %%
# Step 6: Visualize the embeddings.


def plot_with_labels(low_dim_embs, labels, filename='tsne_dl.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)
  plt.show()

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")
